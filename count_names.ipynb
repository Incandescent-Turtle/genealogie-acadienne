# %%
import pandas as pd

df = pd.read_csv("names.csv")
print(f"Total names: {len(df)}")
print(f"Columns: {list(df.columns)}")
df.head()
# Out:
# Total names: 1000
# Columns: ['n_file', 'n_id', 'n_num', 'n_type', 'n_sort', 'n_full', 'n_surname', 'n_surn', 'n_givn', 'n_soundex_givn_std', 'n_soundex_surn_std', 'n_soundex_givn_dm', 'n_soundex_surn_dm']
#    n_file  n_id  n_num n_type                   n_sort  \
# 0       4   100      0   NAME         BOURGEOIS,Claude
# 1       5   100      0   NAME          DOUCET,François
# 2       6   100      0   NAME         d'ENTREMONT,Anne
# 3       7   100      0   NAME            DEVEAU,Joseph
# 4       8   100      0   NAME  GIROUARD,Anne-Charlotte
#
#                        n_full    n_surname       n_surn          n_givn  \
# 0            Claude BOURGEOIS    BOURGEOIS    BOURGEOIS          Claude
# 1  François DOUCET (à Joseph)       DOUCET       DOUCET        François
# 2            Anne d'ENTREMONT  d'ENTREMONT  d'ENTREMONT            Anne
# 3               Joseph DEVEAU       DEVEAU       DEVEAU          Joseph
# ...
